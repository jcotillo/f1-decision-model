# %% [markdown]
# <a href="https://colab.research.google.com/github/jcotillo/f1-decision-model/blob/main/f1data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Explore F1 data

# %%
data_path = '/content/f1_data/'
zip_file = 'f1data.zip'
# !unzip -o {data_path + zip_file} -d {data_path}
# Out:
# Archive:  /content/f1_data/f1data.zip
#   inflating: /content/f1_data/circuits.csv
#   inflating: /content/f1_data/constructor_results.csv
#   inflating: /content/f1_data/constructor_standings.csv
#   inflating: /content/f1_data/constructors.csv
#   inflating: /content/f1_data/driver_standings.csv
#   inflating: /content/f1_data/drivers.csv
#   inflating: /content/f1_data/lap_times.csv
#   inflating: /content/f1_data/pit_stops.csv
#   inflating: /content/f1_data/qualifying.csv
#   inflating: /content/f1_data/races.csv
#   inflating: /content/f1_data/results.csv
#   inflating: /content/f1_data/seasons.csv
#   inflating: /content/f1_data/sprint_results.csv
#   inflating: /content/f1_data/status.csv

# %%
# Here we import all our libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
drivers = pd.read_csv(data_path + 'drivers.csv')
standings = pd.read_csv(data_path + 'driver_standings.csv')
results = pd.read_csv(data_path + 'results.csv')
sprint_results = pd.read_csv(data_path + 'sprint_results.csv')
lap_times = pd.read_csv(data_path + 'lap_times.csv')
pit_stops = pd.read_csv(data_path + 'pit_stops.csv')
display(drivers.head(), standings.head(), results.head(), sprint_results.head(), lap_times.head(), pit_stops.head())
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# ...
